# %% [markdown]
# **Importing the relevant libraries**

# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# **Setup**
#
# set plotting style, loading the file and initialise variables

# %%
# Set plotting style
plt.style.use('ggplot')

# Load data
try:
    df = pd.read_csv("air_quality_clean.csv", index_col="Datetime", parse_dates=True)
except FileNotFoundError:
    # Create dummy data if file doesn't exist for demonstration
    dates = pd.date_range(start="2004-01-01", end="2005-12-31", freq="H")
    df = pd.DataFrame(np.random.rand(len(dates), 5) * 100, index=dates, columns=["CO(GT)", "NMHC(GT)", "C6H6(GT)", "NOx(GT)", "NO2(GT)"])

# Pollutants to model
pollutants = ["CO(GT)", "NMHC(GT)", "C6H6(GT)", "NOx(GT)", "NO2(GT)"]
horizons = [1, 6, 12, 24]
lags = [1, 2, 3, 24]

all_results = []
# Out:
# /tmp/ipython-input-2775715644.py:9: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   dates = pd.date_range(start="2004-01-01", end="2005-12-31", freq="H")

# %% [markdown]
# ## Time Series Forecasting Model Training and Evaluation
#
# This section trains and evaluates multiple machine learning models (Linear Regression, Random Forest, XGBoost, Decision Tree, Neural Network, and Support Vector Machine) for time series forecasting. It iterates through different pollutants and prediction horizons, calculates performance metrics (RMSE), and generates visualizations for the first prediction horizon to compare actual vs. predicted values and analyze residuals.

# %%
for pollutant in pollutants:
    print(f"\n{'='*10} Modelling pollutant: {pollutant} {'='*10}")

    df_temp = df.copy()

    # 1. Create Lag Features
    for lag in lags:
        df_temp[f"{pollutant}_lag_{lag}"] = df_temp[pollutant].shift(lag)

    # 2. Create targets
    for h in horizons:
        df_temp[f"y_{h}"] = df_temp[pollutant].shift(-h)

    # 3. Train/test split
    # We need to be careful to drop NaNs created by shifting
    train = df_temp[df_temp.index.year == 2004].dropna()
    test = df_temp[df_temp.index.year == 2005].dropna()

    # 4. Prepare Features
    # We keep 'pollutant' (current time t) in 'test' temporarily for Baseline calculation
    drop_cols_X = [pollutant] + [f"y_{h}" for h in horizons]

    X_train = train.drop(columns=drop_cols_X)
    X_test = test.drop(columns=drop_cols_X)

    # 5. Scale Data
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    for h in horizons:
        y_train = train[f"y_{h}"]
        y_test = test[f"y_{h}"]

        print(f"\n=== Model training for horizon: {h} ===")

        # --- Naive Baseline ---
        # Prediction for t+h is simply the value at t
        # In our dataframe, test[pollutant] is the value at t
        baseline_pred = test[pollutant]
        rmse_baseline = np.sqrt(mean_squared_error(y_test, baseline_pred))
        print(f"Baseline (Naïve) RMSE: {rmse_baseline:.4f}")

        # --- Linear Regression ---
        print("Linear Regression model training...")
        start_time = time.time()
        lr = LinearRegression()
        lr.fit(X_train_scaled, y_train)
        pred_lr = lr.predict(X_test_scaled)
        rmse_lr = np.sqrt(mean_squared_error(y_test, pred_lr))
        print(f"Finished Linear Regression! Time: {time.time() - start_time:.2f}s, RMSE: {rmse_lr:.4f}")

        # --- Random Forest ---
        print("Random Forest model training...")
        start_time = time.time()
        rf = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1)
        rf.fit(X_train, y_train)
        pred_rf = rf.predict(X_test)
        rmse_rf = np.sqrt(mean_squared_error(y_test, pred_rf))
        print(f"Finished Random Forest! Time: {time.time() - start_time:.2f}s, RMSE: {rmse_rf:.4f}")

        # --- XGBoost ---
        print("XGBoost model training...")
        start_time = time.time()
        xgb = XGBRegressor(n_estimators=200, learning_rate=0.05, random_state=42, n_jobs=-1)
        xgb.fit(X_train, y_train)
        pred_xgb = xgb.predict(X_test)
        rmse_xgb = np.sqrt(mean_squared_error(y_test, pred_xgb))
        print(f"Finished XGBoost! Time: {time.time() - start_time:.2f}s, RMSE: {rmse_xgb:.4f}")

        # --- Decision Tree ---
        print("Decision Tree model training...")
        start_time = time.time()
        dt = DecisionTreeRegressor(max_depth=10, random_state=42)
        dt.fit(X_train, y_train)
        pred_dt = dt.predict(X_test)
        rmse_dt = np.sqrt(mean_squared_error(y_test, pred_dt))
        print(f"Finished Decision Tree! Time: {time.time() - start_time:.2f}s, RMSE: {rmse_dt:.4f}")

        # --- Neural Network ---
        print("Neural Network (MLP) model training...")
        start_time = time.time()
        nn = MLPRegressor(hidden_layer_sizes=(50, 30), max_iter=500, random_state=42, early_stopping=True)
        nn.fit(X_train_scaled, y_train)
        pred_nn = nn.predict(X_test_scaled)
        rmse_nn = np.sqrt(mean_squared_error(y_test, pred_nn))
        print(f"Finished Neural Network! Time: {time.time() - start_time:.2f}s, RMSE: {rmse_nn:.4f}")

        # --- SVM ---
        print("Support Vector Machine (SVR) model training...")
        start_time = time.time()
        svr = SVR(kernel='rbf', C=1.0, epsilon=0.1)
        svr.fit(X_train_scaled, y_train)
        pred_svr = svr.predict(X_test_scaled)
        rmse_svr = np.sqrt(mean_squared_error(y_test, pred_svr))
        print(f"Finished SVR! Time: {time.time() - start_time:.2f}s, RMSE: {rmse_svr:.4f}")

        all_results.append([pollutant, h, rmse_baseline, rmse_lr, rmse_rf, rmse_xgb, rmse_dt, rmse_svr, rmse_nn])

        # --- Visualisation (Only for Horizon = 1 to save space/time) ---
        if h == 1:
            # 1. Trend Plot (Actual vs Predicted - First 150 hours for clarity)
            plt.figure(figsize=(12, 5))
            subset_n = 150
            plt.plot(y_test.index[:subset_n], y_test.values[:subset_n], label='Actual', color='black', alpha=0.7)
            plt.plot(y_test.index[:subset_n], pred_rf[:subset_n], label='Random Forest', color='blue', alpha=0.7)
            plt.plot(y_test.index[:subset_n], pred_lr[:subset_n], label='Linear Reg', color='green', linestyle='--', alpha=0.7)
            plt.title(f'Forecast Trends: {pollutant} (Horizon h={h})')
            plt.xlabel('Date')
            plt.ylabel('Concentration')
            plt.legend()
            plt.savefig(f'trend_{pollutant}_h{h}.png')
            plt.close()

            # 2. Residual Plot (Random Forest Residuals)
            residuals = y_test - pred_rf
            plt.figure(figsize=(12, 5))
            plt.scatter(y_test, residuals, alpha=0.3, color='red')
            plt.axhline(0, color='black', linestyle='--')
            plt.title(f'Residual Plot (Random Forest): {pollutant} (Horizon h={h})')
            plt.xlabel('Actual Values')
            plt.ylabel('Residuals (Actual - Predicted)')
            plt.savefig(f'residuals_{pollutant}_h{h}.png')
            plt.close()


print("Model Training and Evaluation finished")
# Out:
# ========== Modelling pollutant: CO(GT) ==========
#
# === Model training for horizon: 1 ===
# Baseline (Naïve) RMSE: 40.3971
# Linear Regression model training...
# Finished Linear Regression! Time: 0.01s, RMSE: 28.8622
# Random Forest model training...
# Finished Random Forest! Time: 13.31s, RMSE: 29.2839
# XGBoost model training...
# Finished XGBoost! Time: 2.26s, RMSE: 29.4330
# Decision Tree model training...
# Finished Decision Tree! Time: 0.17s, RMSE: 30.0134
# Neural Network (MLP) model training...
# Finished Neural Network! Time: 5.38s, RMSE: 29.0710
# Support Vector Machine (SVR) model training...
# Finished SVR! Time: 8.71s, RMSE: 28.9633
#
# === Model training for horizon: 6 ===
# Baseline (Naïve) RMSE: 40.9393
# Linear Regression model training...
# Finished Linear Regression! Time: 0.00s, RMSE: 28.8807
# Random Forest model training...
# Finished Random Forest! Time: 14.13s, RMSE: 29.2719
# XGBoost model training...
# Finished XGBoost! Time: 2.40s, RMSE: 29.3616
# Decision Tree model training...
# Finished Decision Tree! Time: 0.17s, RMSE: 30.1820
# Neural Network (MLP) model training...
# Finished Neural Network! Time: 5.88s, RMSE: 29.1074
# Support Vector Machine (SVR) model training...
# Finished SVR! Time: 9.58s, RMSE: 28.9820
#
# === Model training for horizon: 12 ===
# Baseline (Naïve) RMSE: 40.4329
# Linear Regression model training...
# Finished Linear Regression! Time: 0.00s, RMSE: 28.8686
# Random Forest model training...
# Finished Random Forest! Time: 14.06s, RMSE: 29.3331
# XGBoost model training...
# Finished XGBoost! Time: 0.72s, RMSE: 29.4046
# Decision Tree model training...
# Finished Decision Tree! Time: 0.13s, RMSE: 29.9473
# Neural Network (MLP) model training...
# Finished Neural Network! Time: 5.10s, RMSE: 29.0845
# Support Vector Machine (SVR) model training...
# Finished SVR! Time: 7.46s, RMSE: 28.9525
#
# === Model training for horizon: 24 ===
# Baseline (Naïve) RMSE: 40.7644
# Linear Regression model training...
# Finished Linear Regression! Time: 0.00s, RMSE: 28.8343
# Random Forest model training...
# Finished Random Forest! Time: 13.39s, RMSE: 29.2127
# XGBoost model training...
# Finished XGBoost! Time: 0.74s, RMSE: 29.3542
# Decision Tree model training...
# Finished Decision Tree! Time: 0.13s, RMSE: 30.4980
# Neural Network (MLP) model training...
# Finished Neural Network! Time: 6.25s, RMSE: 29.0684
# Support Vector Machine (SVR) model training...
# Finished SVR! Time: 7.43s, RMSE: 28.9593
#
# ========== Modelling pollutant: NMHC(GT) ==========
#
# === Model training for horizon: 1 ===
# Baseline (Naïve) RMSE: 41.1732
# Linear Regression model training...
# Finished Linear Regression! Time: 0.00s, RMSE: 29.1028
# Random Forest model training...
# Finished Random Forest! Time: 13.08s, RMSE: 29.6150
# XGBoost model training...
# Finished XGBoost! Time: 0.72s, RMSE: 29.6540
# Decision Tree model training...
# Finished Decision Tree! Time: 0.13s, RMSE: 30.3694
# Neural Network (MLP) model training...
# Finished Neural Network! Time: 5.71s, RMSE: 29.3118
# Support Vector Machine (SVR) model training...
# Finished SVR! Time: 7.43s, RMSE: 29.2125
#
# === Model training for horizon: 6 ===
# Baseline (Naïve) RMSE: 41.3101
# Linear Regression model training...
# Finished Linear Regression! Time: 0.00s, RMSE: 29.0949
# Random Forest model training...
# Finished Random Forest! Time: 15.69s, RMSE: 29.6397
# XGBoost model training...
# Finished XGBoost! Time: 2.07s, RMSE: 29.7010
# Decision Tree model training...
# Finished Decision Tree! Time: 0.13s, RMSE: 29.8588
# Neural Network (MLP) model training...
# Finished Neural Network! Time: 3.50s, RMSE: 29.2766
# Support Vector Machine (SVR) model training...
# Finished SVR! Time: 8.54s, RMSE: 29.1785
#
# === Model training for horizon: 12 ===
# Baseline (Naïve) RMSE: 40.7088
# Linear Regression model training...
# Finished Linear Regression! Time: 0.02s, RMSE: 29.0870
# Random Forest model training...
# Finished Random Forest! Time: 13.36s, RMSE: 29.5397
# XGBoost model training...
# Finished XGBoost! Time: 0.90s, RMSE: 29.5909
# Decision Tree model training...
# Finished Decision Tree! Time: 0.12s, RMSE: 30.2663
# Neural Network (MLP) model training...
# Finished Neural Network! Time: 3.57s, RMSE: 29.2626
# Support Vector Machine (SVR) model training...
# Finished SVR! Time: 8.73s, RMSE: 29.1602
#
# === Model training for horizon: 24 ===
# Baseline (Naïve) RMSE: 41.1754
# Linear Regression model training...
# Finished Linear Regression! Time: 0.00s, RMSE: 29.1117
# Random Forest model training...
# Finished Random Forest! Time: 12.96s, RMSE: 29.5503
# XGBoost model training...
# Finished XGBoost! Time: 0.69s, RMSE: 29.6880
# Decision Tree model training...
# Finished Decision Tree! Time: 0.13s, RMSE: 30.7339
# Neural Network (MLP) model training...
# Finished Neural Network! Time: 4.72s, RMSE: 29.3375
# Support Vector Machine (SVR) model training...
# Finished SVR! Time: 9.12s, RMSE: 29.2211
#
# ========== Modelling pollutant: C6H6(GT) ==========
#
# === Model training for horizon: 1 ===
# Baseline (Naïve) RMSE: 41.1725
# Linear Regression model training...
# Finished Linear Regression! Time: 0.00s, RMSE: 28.7894
# Random Forest model training...
# Finished Random Forest! Time: 13.30s, RMSE: 29.2996
# XGBoost model training...
# Finished XGBoost! Time: 0.73s, RMSE: 29.3821
# Decision Tree model training...
# Finished Decision Tree! Time: 0.13s, RMSE: 30.2502
# Neural Network (MLP) model training...
# Finished Neural Network! Time: 3.83s, RMSE: 28.9458
# Support Vector Machine (SVR) model training...
# Finished SVR! Time: 8.69s, RMSE: 28.8963
#
# === Model training for horizon: 6 ===
# Baseline (Naïve) RMSE: 40.6537
# Linear Regression model training...
# Finished Linear Regression! Time: 0.00s, RMSE: 28.7859
# Random Forest model training...
# Finished Random Forest! Time: 14.00s, RMSE: 29.1870
# XGBoost model training...
# Finished XGBoost! Time: 0.70s, RMSE: 29.2963
# Decision Tree model training...
# Finished Decision Tree! Time: 0.13s, RMSE: 29.3908
# Neural Network (MLP) model training...
# Finished Neural Network! Time: 3.15s, RMSE: 29.0819
# Support Vector Machine (SVR) model training...
# Finished SVR! Time: 8.51s, RMSE: 28.9198
#
# === Model training for horizon: 12 ===
# Baseline (Naïve) RMSE: 40.5627
# Linear Regression model training...
# Finished Linear Regression! Time: 0.00s, RMSE: 28.7669
# Random Forest model training...
# Finished Random Forest! Time: 13.99s, RMSE: 29.1777
# XGBoost model training...
# Finished XGBoost! Time: 0.73s, RMSE: 29.1958
# Decision Tree model training...
# Finished Decision Tree! Time: 0.12s, RMSE: 30.9237
# Neural Network (MLP) model training...
# Finished Neural Network! Time: 2.76s, RMSE: 28.9638
# Support Vector Machine (SVR) model training...
# Finished SVR! Time: 8.57s, RMSE: 28.8534
#
# === Model training for horizon: 24 ===
# Baseline (Naïve) RMSE: 40.8646
# Linear Regression model training...
# Finished Linear Regression! Time: 0.00s, RMSE: 28.7729
# Random Forest model training...
# Finished Random Forest! Time: 13.86s, RMSE: 29.1876
# XGBoost model training...
# Finished XGBoost! Time: 0.70s, RMSE: 29.3741
# Decision Tree model training...
# Finished Decision Tree! Time: 0.13s, RMSE: 29.8709
# Neural Network (MLP) model training...
# Finished Neural Network! Time: 3.75s, RMSE: 28.8856
# Support Vector Machine (SVR) model training...
# Finished SVR! Time: 8.50s, RMSE: 28.8361
#
# ========== Modelling pollutant: NOx(GT) ==========
#
# === Model training for horizon: 1 ===
# Baseline (Naïve) RMSE: 41.0393
# Linear Regression model training...
# Finished Linear Regression! Time: 0.00s, RMSE: 28.7970
# Random Forest model training...
# Finished Random Forest! Time: 12.80s, RMSE: 29.2717
# XGBoost model training...
# Finished XGBoost! Time: 0.73s, RMSE: 29.3949
# Decision Tree model training...
# Finished Decision Tree! Time: 0.12s, RMSE: 30.7023
# Neural Network (MLP) model training...
# Finished Neural Network! Time: 3.63s, RMSE: 29.0578
# Support Vector Machine (SVR) model training...
# Finished SVR! Time: 8.53s, RMSE: 28.9123
#
# === Model training for horizon: 6 ===
# Baseline (Naïve) RMSE: 41.0376
# Linear Regression model training...
# Finished Linear Regression! Time: 0.00s, RMSE: 28.8015
# Random Forest model training...
# Finished Random Forest! Time: 13.82s, RMSE: 29.2275
# XGBoost model training...
# Finished XGBoost! Time: 0.94s, RMSE: 29.3586
# Decision Tree model training...
# Finished Decision Tree! Time: 0.13s, RMSE: 30.2693
# Neural Network (MLP) model training...
# Finished Neural Network! Time: 6.99s, RMSE: 29.0629
# Support Vector Machine (SVR) model training...
# Finished SVR! Time: 7.47s, RMSE: 28.9336
#
# === Model training for horizon: 12 ===
# Baseline (Naïve) RMSE: 40.5127
# Linear Regression model training...
# Finished Linear Regression! Time: 0.00s, RMSE: 28.8000
# Random Forest model training...
# Finished Random Forest! Time: 14.40s, RMSE: 29.2163
# XGBoost model training...
# Finished XGBoost! Time: 0.71s, RMSE: 29.3077
# Decision Tree model training...
# Finished Decision Tree! Time: 0.13s, RMSE: 29.3850
# Neural Network (MLP) model training...
# Finished Neural Network! Time: 6.02s, RMSE: 29.0161
# Support Vector Machine (SVR) model training...
# Finished SVR! Time: 7.43s, RMSE: 28.9052
#
# === Model training for horizon: 24 ===
# Baseline (Naïve) RMSE: 40.7503
# Linear Regression model training...
# Finished Linear Regression! Time: 0.00s, RMSE: 28.7762
# Random Forest model training...
# Finished Random Forest! Time: 13.26s, RMSE: 29.2479
# XGBoost model training...
# Finished XGBoost! Time: 0.74s, RMSE: 29.2167
# Decision Tree model training...
# Finished Decision Tree! Time: 0.13s, RMSE: 29.5352
# Neural Network (MLP) model training...
# Finished Neural Network! Time: 5.67s, RMSE: 28.9668
# Support Vector Machine (SVR) model training...
# Finished SVR! Time: 7.39s, RMSE: 28.8675
#
# ========== Modelling pollutant: NO2(GT) ==========
#
# === Model training for horizon: 1 ===
# Baseline (Naïve) RMSE: 41.2245
# Linear Regression model training...
# Finished Linear Regression! Time: 0.00s, RMSE: 28.8231
# Random Forest model training...
# Finished Random Forest! Time: 13.60s, RMSE: 29.3839
# XGBoost model training...
# Finished XGBoost! Time: 1.06s, RMSE: 29.3517
# Decision Tree model training...
# Finished Decision Tree! Time: 0.17s, RMSE: 30.4639
# Neural Network (MLP) model training...
# Finished Neural Network! Time: 4.98s, RMSE: 29.0504
# Support Vector Machine (SVR) model training...
# Finished SVR! Time: 7.43s, RMSE: 28.9085
#
# === Model training for horizon: 6 ===
# Baseline (Naïve) RMSE: 40.9275
# Linear Regression model training...
# Finished Linear Regression! Time: 0.02s, RMSE: 28.8078
# Random Forest model training...
# Finished Random Forest! Time: 14.46s, RMSE: 29.2094
# XGBoost model training...
# Finished XGBoost! Time: 1.94s, RMSE: 29.3512
# Decision Tree model training...
# Finished Decision Tree! Time: 0.14s, RMSE: 29.4936
# Neural Network (MLP) model training...
# Finished Neural Network! Time: 3.32s, RMSE: 29.0234
# Support Vector Machine (SVR) model training...
# Finished SVR! Time: 8.43s, RMSE: 28.9047
#
# === Model training for horizon: 12 ===
# Baseline (Naïve) RMSE: 41.0159
# Linear Regression model training...
# Finished Linear Regression! Time: 0.00s, RMSE: 28.8084
# Random Forest model training...
# Finished Random Forest! Time: 14.41s, RMSE: 29.2503
# XGBoost model training...
# Finished XGBoost! Time: 0.72s, RMSE: 29.4136
# Decision Tree model training...
# Finished Decision Tree! Time: 0.14s, RMSE: 30.9203
# Neural Network (MLP) model training...
# Finished Neural Network! Time: 3.44s, RMSE: 29.0400
# Support Vector Machine (SVR) model training...
# Finished SVR! Time: 8.71s, RMSE: 28.8927
#
# === Model training for horizon: 24 ===
# Baseline (Naïve) RMSE: 40.7122
# Linear Regression model training...
# Finished Linear Regression! Time: 0.00s, RMSE: 28.8212
# Random Forest model training...
# Finished Random Forest! Time: 13.50s, RMSE: 29.2543
# XGBoost model training...
# Finished XGBoost! Time: 0.73s, RMSE: 29.2576
# Decision Tree model training...
# Finished Decision Tree! Time: 0.13s, RMSE: 30.2543
# Neural Network (MLP) model training...
# Finished Neural Network! Time: 2.86s, RMSE: 29.1025
# Support Vector Machine (SVR) model training...
# Finished SVR! Time: 8.72s, RMSE: 28.9324

# %% [markdown]
# **Convert to DataFrame**

# %%
df_all_results = pd.DataFrame(
    all_results,
    columns=[
        'Pollutant',
        'Horizon',
        'Baseline RMSE',
        'Linear Regression RMSE',
        'Random Forest RMSE',
        'XGBoost RMSE',
        'Decision Tree RMSE',
        'SVM RMSE',
        'Neural Network RMSE'
    ]
)

# %% [markdown]
# **Prints formatted tables**

# %%
print("\n" + "="*30)
print(" FINAL RESULTS TABLES ")
print("="*30)

for pollutant in pollutants:
    print(f"\nResults for {pollutant}:")
    display_df = df_all_results[df_all_results['Pollutant'] == pollutant].drop(columns=['Pollutant'])
    display_df = display_df.reset_index(drop=True)
    print(display_df.to_string())
    print("-" * 100)
# Out:
# ==============================
#  FINAL RESULTS TABLES
# ==============================
#
# Results for CO(GT):
#    Horizon  Baseline RMSE  Linear Regression RMSE  Random Forest RMSE  XGBoost RMSE  Decision Tree RMSE   SVM RMSE  Neural Network RMSE
# 0        1      40.397088               28.862190           29.283900     29.432991           30.013379  28.963318            29.071015
# 1        6      40.939251               28.880710           29.271854     29.361564           30.181950  28.982004            29.107408
# 2       12      40.432898               28.868608           29.333053     29.404639           29.947312  28.952514            29.084482
# 3       24      40.764403               28.834315           29.212686     29.354215           30.498030  28.959333            29.068402
# ----------------------------------------------------------------------------------------------------
#
# Results for NMHC(GT):
#    Horizon  Baseline RMSE  Linear Regression RMSE  Random Forest RMSE  XGBoost RMSE  Decision Tree RMSE   SVM RMSE  Neural Network RMSE
# 0        1      41.173207               29.102850           29.614972     29.653994           30.369446  29.212549            29.311833
# 1        6      41.310088               29.094868           29.639696     29.700978           29.858793  29.178497            29.276580
# 2       12      40.708799               29.087011           29.539718     29.590856           30.266274  29.160206            29.262607
# 3       24      41.175371               29.111659           29.550271     29.688040           30.733913  29.221061            29.337485
# ----------------------------------------------------------------------------------------------------
#
# Results for C6H6(GT):
#    Horizon  Baseline RMSE  Linear Regression RMSE  Random Forest RMSE  XGBoost RMSE  Decision Tree RMSE   SVM RMSE  Neural Network RMSE
# 0        1      41.172536               28.789351           29.299593     29.382147           30.250169  28.896309            28.945764
# 1        6      40.653658               28.785904           29.187029     29.296284           29.390762  28.919753            29.081893
# 2       12      40.562695               28.766904           29.177711     29.195817           30.923669  28.853420            28.963758
# 3       24      40.864638               28.772859           29.187636     29.374105           29.870852  28.836094            28.885590
# ----------------------------------------------------------------------------------------------------
#
# Results for NOx(GT):
#    Horizon  Baseline RMSE  Linear Regression RMSE  Random Forest RMSE  XGBoost RMSE  Decision Tree RMSE   SVM RMSE  Neural Network RMSE
# 0        1      41.039284               28.797032           29.271737     29.394935           30.702282  28.912317            29.057782
# 1        6      41.037598               28.801521           29.227477     29.358572           30.269334  28.933586            29.062857
# 2       12      40.512693               28.799986           29.216290     29.307658           29.384958  28.905233            29.016101
# 3       24      40.750260               28.776241           29.247863     29.216669           29.535246  28.867480            28.966799
# ----------------------------------------------------------------------------------------------------
#
# Results for NO2(GT):
#    Horizon  Baseline RMSE  Linear Regression RMSE  Random Forest RMSE  XGBoost RMSE  Decision Tree RMSE   SVM RMSE  Neural Network RMSE
# 0        1      41.224503               28.823074           29.383877     29.351656           30.463898  28.908498            29.050354
# 1        6      40.927492               28.807762           29.209416     29.351232           29.493604  28.904682            29.023390
# 2       12      41.015880               28.808412           29.250280     29.413626           30.920306  28.892651            29.039997
# 3       24      40.712155               28.821247           29.254311     29.257562           30.254350  28.932409            29.102460
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# **Export results**

# %%
print("\n=== Exporting Data ===")

# Export to CSV
try:
    csv_filename = "air_quality_results.csv"
    df_all_results.to_csv(csv_filename, index=False)
    print(f"Successfully saved results to '{csv_filename}'")
except Exception as e:
    print(f"Error saving CSV: {e}")

# Export to Excel
try:
    xlsx_filename = "air_quality_results.xlsx"
    df_all_results.to_excel(xlsx_filename, index=False)
    print(f"Successfully saved results to '{xlsx_filename}'")
except ImportError:
    print(f"Could not save to Excel ({xlsx_filename}). Missing dependency.\nPlease run: pip install openpyxl")
except Exception as e:
    print(f"Error saving Excel: {e}")

# %% [markdown]
# ## Observation and Results Summary
#
# Based on the results from the model training and evaluation, here's a summary of the conclusions:
#
# 1.  **Significant Improvement Over Baseline**: All implemented machine learning models (Linear Regression, Random Forest, XGBoost, Decision Tree, Neural Network, and SVM) consistently achieved significantly lower RMSE values compared to the Baseline (Naïve) model across all pollutants and prediction horizons. This indicates that even simple machine learning approaches are much more effective than a naive forecast for this dataset.
#
# 2.  **Top Performing Models**: Linear Regression, Support Vector Machine (SVM), and Neural Network (MLP) models generally showed the best performance, often yielding the lowest RMSE values for most pollutants and horizons.
#
# 3.  **Intermediate Performers**: Random Forest and XGBoost models performed well, consistently outperforming the Baseline and Decision Tree, but were often slightly behind Linear Regression, SVM, and Neural Networks in terms of RMSE.
#
# 4.  **Decision Tree Performance**: The Decision Tree Regressor consistently had higher RMSE values compared to other machine learning models, suggesting it was the least effective among the advanced models for this forecasting task.
#
# 5.  **Consistency Across Horizons**: The relative performance rankings of the models remained fairly consistent across different prediction horizons (1, 6, 12, and 24 hours). There wasn't a single model that drastically improved or worsened its relative standing at longer horizons.
#
# In essence, the advanced models provide robust improvements over simple baseline methods, with Linear Regression, SVM, and Neural Networks showing the strongest predictive power for this time series forecasting problem.
